# %% [markdown]
# # Querying the *flight phase files*
# We introduce here some new methods, that we will use to select the flight segments, querying for different criteria.
#
# ## Data access
# * To load the data we first load the (AC)³airborne meta data catalogue. More information on the catalog can be found [here](https://github.com/igmk/ac3airborne-intake#ac3airborne-intake-catalogue).

# %%
import ac3airborne

# %%
cat = ac3airborne.get_intake_catalog()
list(cat.Polar5.MIRAC_A)
# Out:
# ['ACLOUD_P5_RF04',
#  'ACLOUD_P5_RF05',
#  'ACLOUD_P5_RF06',
#  'ACLOUD_P5_RF07',
#  'ACLOUD_P5_RF08',
#  'ACLOUD_P5_RF10',
#  'ACLOUD_P5_RF11',
#  'ACLOUD_P5_RF15',
#  'ACLOUD_P5_RF17',
#  'ACLOUD_P5_RF18',
#  'ACLOUD_P5_RF19',
#  'ACLOUD_P5_RF20',
#  'ACLOUD_P5_RF21',
#  'ACLOUD_P5_RF22',
#  'ACLOUD_P5_RF23',
#  'ACLOUD_P5_RF25',
#  'AFLUX_P5_RF03',
#  'AFLUX_P5_RF04',
#  'AFLUX_P5_RF05',
#  'AFLUX_P5_RF06',
#  'AFLUX_P5_RF07',
#  'AFLUX_P5_RF08',
#  'AFLUX_P5_RF09',
#  'AFLUX_P5_RF10',
#  'AFLUX_P5_RF11',
#  'AFLUX_P5_RF12',
#  'AFLUX_P5_RF13',
#  'AFLUX_P5_RF14',
#  'AFLUX_P5_RF15',
#  'MOSAiC-ACA_P5_RF05',
#  'MOSAiC-ACA_P5_RF06',
#  'MOSAiC-ACA_P5_RF07',
#  'MOSAiC-ACA_P5_RF08',
#  'MOSAiC-ACA_P5_RF09',
#  'MOSAiC-ACA_P5_RF10',
#  'MOSAiC-ACA_P5_RF11']

# %% [markdown]
# ```{note}
# Have a look at the attributes of the xarray dataset `ds_mirac_a` for all relevant information on the dataset, such as author, contact, or citation infromation.
# ```

# %% [markdown]
# In this example we want to look at `ACLOUD_P5_RF14`. First we read the GPS information:

# %%
ds_gps = cat['Polar5']['GPS_INS']['ACLOUD_P5_RF14'].to_dask()
ds_gps
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 20211)
# Coordinates:
#   * time     (time) datetime64[ns] 2017-06-08T07:22:07 ... 2017-06-08T12:59:07
# Data variables:
#     alt      (time) float64 ...
#     tas      (time) float64 ...
#     lat      (time) float64 ...
#     lat_dir  (time) object ...
#     lon      (time) float64 ...
#     lon_dir  (time) object ...
#     vs       (time) float64 ...
#     gs       (time) float64 ...
#     pitch    (time) float64 ...
#     roll     (time) float64 ...
#     heading  (time) float64 ...
# Attributes: (12/14)
#     description:  1Hz subset based on GPS1 and INS data processed by AWI engi...
#     instruments:  GPS1 and INS
#     version:      [0.1]
#     contact:      mario.mech@uni-koeln.de, martin.gehrmann@awi.de
#     institution:  ['Alfred-Wegener-Institut Helmholtz-Zentrum für Polar- und ...
#     author:       Dr. Mario Mech
#     ...           ...
#     featureType:  trajectory
#     mission:      ACLOUD
#     platform:     Polar5
#     flight_id:    RF14
#     title:        Polar5 position and attitude data
#     history:      acquired by Polar5 during ACLOUD campaign, quality checked ...

# %% [markdown]
# ## Import flightphase module

# %%
from ac3airborne.tools import flightphase as fp

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ## Load Polar 5 flight phase information
# Polar 5 flights are divided into segments to easily access start and end times of flight patterns. For more information have a look at the respective [github](https://github.com/igmk/flight-phase-separation) repository.
#
# At first we want to load the flight segments of (AC)³airborne

# %%
meta = ac3airborne.get_flight_segments()

# %% [markdown]
# The next step is to select the flight segments of our flight:

# %%
flight = meta['P5']['ACLOUD_P5_RF14']

# %%
ds = fp.FlightPhaseFile(flight)

# %% [markdown]
# ## Plot entire flight

# %%
proj   = ccrs.NorthPolarStereo()
extent = (-5.0, 24.0, 78.0, 83.0)

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=proj)
ax.set_extent(extent)

ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND)
ax.gridlines()
ax.coastlines()

nya_lat = 78.924444
nya_lon = 11.928611

ax.plot(nya_lon, nya_lat, 'ro', transform=ccrs.PlateCarree())
ax.text(nya_lon, nya_lat+0.05, 'Ny-Ålesund', transform=ccrs.PlateCarree())

line_all = ax.plot(ds_gps.lon, ds_gps.lat, transform=ccrs.PlateCarree())

plt.show()

# %% [markdown]
# ### Query all segments of a specific kind

# %% [markdown]
# Example with one kind

# %%
queried = ds.selectKind(['high_level'])

df = pd.DataFrame(queried)
df
# Out:
#                                           dropsondes                 end  \
# 0                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:25:57
# 1  {'BAD': [], 'GOOD': ['P5_RF14_sonde02'], 'UGLY... 2017-06-08 08:58:26
# 2  {'BAD': [], 'GOOD': ['P5_RF14_sonde03'], 'UGLY... 2017-06-08 09:30:30
# 3  {'BAD': [], 'GOOD': ['P5_RF14_sonde04'], 'UGLY... 2017-06-08 09:51:04
# 4  {'BAD': [], 'GOOD': ['P5_RF14_sonde05'], 'UGLY... 2017-06-08 10:00:14
# 5  {'BAD': ['P5_RF14_sonde06'], 'GOOD': [], 'UGLY... 2017-06-08 11:52:57
# 6  {'BAD': [], 'GOOD': ['P5_RF14_sonde07'], 'UGLY... 2017-06-08 12:05:14
#
#   irregularities                              kinds  levels          name  \
# 0             []                       [high_level]  [9800]  high level 1
# 1             []                       [high_level]  [9800]  high level 2
# 2             []  [high_level, a-train_underflight]  [9700]  high level 3
# 3             []                       [high_level]  [9700]  high level 4
# 4             []                       [high_level]  [9800]  high level 5
# 5             []                       [high_level]  [9700]  high level 6
# 6             []                       [high_level]  [9800]  high level 7
#
#             segment_id               start
# 0  ACLOUD_P5_RF14_hl01 2017-06-08 08:08:54
# 1  ACLOUD_P5_RF14_hl02 2017-06-08 08:36:30
# 2  ACLOUD_P5_RF14_hl03 2017-06-08 08:59:08
# 3  ACLOUD_P5_RF14_hl04 2017-06-08 09:31:41
# 4  ACLOUD_P5_RF14_hl05 2017-06-08 09:51:33
# 5  ACLOUD_P5_RF14_hl06 2017-06-08 11:11:20
# 6  ACLOUD_P5_RF14_hl07 2017-06-08 11:53:38

# %% [markdown]
# Plot the selected segments:

# %%
ll = line_all.pop(0)
ll.remove()

lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
#  Example with more than one kind

# %%
kinds = ['a-train_underflight', 'nya_overflight', 'polarstern_overflight']

queried = ds.selectKind(kinds)

df = pd.DataFrame(queried)
df
# Out:
#                                           dropsondes                 end  \
# 0                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:08:54
# 1  {'BAD': [], 'GOOD': ['P5_RF14_sonde03'], 'UGLY... 2017-06-08 09:30:30
# 2                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 10:10:51
# 3                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 12:25:40
#
#           irregularities                                              kinds  \
# 0  [whale-watching loop]  [major_ascend, nya_overflight, sveabreen_glaci...
# 1                     []                  [high_level, a-train_underflight]
# 2                     []             [cross_pattern, polarstern_overflight]
# 3                     []                    [cross_pattern, nya_overflight]
#
#                levels             name           segment_id  \
# 0         [100, 9700]     major ascend    ACLOUD_P5_RF14_ma
# 1              [9700]     high level 3  ACLOUD_P5_RF14_hl03
# 2        [9600, 9700]  cross pattern 1  ACLOUD_P5_RF14_cr01
# 3  [9800, 9800, 9800]  cross pattern 2  ACLOUD_P5_RF14_cr02
#
#                 start                                              parts
# 0 2017-06-08 07:36:50                                                NaN
# 1 2017-06-08 08:59:08                                                NaN
# 2 2017-06-08 10:00:14  [{'end': 2017-06-08 10:03:14, 'irregularities'...
# 3 2017-06-08 12:05:14  [{'end': 2017-06-08 12:10:14, 'irregularities'...

# %% [markdown]
# Plot the selected segments:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
# ### Sorting out all segments given a list of kinds

# %%
sort_out = ['short_turn', 'holding_pattern', 'major_ascend', 'major_descend', 'high_level']

queried = ds.selectKind(sort_out, invertSelection=True)

df = pd.DataFrame(queried)
df
# Out:
#                             dropsondes                 end  \
# 0  {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 10:10:51
# 1  {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 10:22:44
# 2  {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 11:02:02
# 3  {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 11:11:20
# 4  {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 12:25:40
#
#               irregularities                                   kinds  \
# 0                         []  [cross_pattern, polarstern_overflight]
# 1  [not along straight line]                         [large_descend]
# 2                         []                     [racetrack_pattern]
# 3                         []                          [large_ascend]
# 4                         []         [cross_pattern, nya_overflight]
#
#                    levels                 name  \
# 0            [9600, 9700]      cross pattern 1
# 1             [9700, 200]      large descend 1
# 2  [200, 300, 1500, 2400]  racetrack pattern 1
# 3            [2400, 9700]       large ascend 1
# 4      [9800, 9800, 9800]      cross pattern 2
#
#                                                parts           segment_id  \
# 0  [{'end': 2017-06-08 10:03:14, 'irregularities'...  ACLOUD_P5_RF14_cr01
# 1                                                NaN  ACLOUD_P5_RF14_ld01
# 2  [{'end': 2017-06-08 10:29:21, 'irregularities'...  ACLOUD_P5_RF14_rt01
# 3                                                NaN  ACLOUD_P5_RF14_la01
# 4  [{'end': 2017-06-08 12:10:14, 'irregularities'...  ACLOUD_P5_RF14_cr02
#
#                 start
# 0 2017-06-08 10:00:14
# 1 2017-06-08 10:10:51
# 2 2017-06-08 10:22:44
# 3 2017-06-08 11:02:25
# 4 2017-06-08 12:05:14

# %% [markdown]
# Plot the selected segments:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
# ### Query a segment with a specific value in a specific attribute

# %% [markdown]
# #### Example 1: Select element with specific name

# %%
attribute = 'name'
value = 'racetrack pattern 1'

queried = ds.select(attribute, value) 

df = pd.DataFrame(queried)
df
# Out:
#                             dropsondes                 end irregularities  \
# 0  {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 11:02:02             []
#
#                  kinds                  levels                 name  \
# 0  [racetrack_pattern]  [200, 300, 1500, 2400]  racetrack pattern 1
#
#                                                parts           segment_id  \
# 0  [{'end': 2017-06-08 10:29:21, 'irregularities'...  ACLOUD_P5_RF14_rt01
#
#                 start
# 0 2017-06-08 10:22:44

# %% [markdown]
# Plot the selected elements:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
# Also with inverted selection

# %%
queried = ds.select(attribute, value, invertSelection=True) 

df = pd.DataFrame(queried)
df
# Out:
#                                            dropsondes                 end  \
# 0                 {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:08:54
# 1                 {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:25:57
# 2                 {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:36:30
# 3   {'BAD': [], 'GOOD': ['P5_RF14_sonde02'], 'UGLY... 2017-06-08 08:58:26
# 4                                                 NaN 2017-06-08 08:59:08
# 5   {'BAD': [], 'GOOD': ['P5_RF14_sonde03'], 'UGLY... 2017-06-08 09:30:30
# 6                                                 NaN 2017-06-08 09:31:41
# 7   {'BAD': [], 'GOOD': ['P5_RF14_sonde04'], 'UGLY... 2017-06-08 09:51:04
# 8                                                 NaN 2017-06-08 09:51:33
# 9   {'BAD': [], 'GOOD': ['P5_RF14_sonde05'], 'UGLY... 2017-06-08 10:00:14
# 10                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 10:10:51
# 11                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 10:22:44
# 12                                                NaN 2017-06-08 11:02:25
# 13                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 11:11:20
# 14  {'BAD': ['P5_RF14_sonde06'], 'GOOD': [], 'UGLY... 2017-06-08 11:52:57
# 15                                                NaN 2017-06-08 11:53:38
# 16  {'BAD': [], 'GOOD': ['P5_RF14_sonde07'], 'UGLY... 2017-06-08 12:05:14
# 17                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 12:25:40
# 18                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 12:51:25
#
#                irregularities  \
# 0       [whale-watching loop]
# 1                          []
# 2                          []
# 3                          []
# 4                         NaN
# 5                          []
# 6                         NaN
# 7                          []
# 8                         NaN
# 9                          []
# 10                         []
# 11  [not along straight line]
# 12                        NaN
# 13                         []
# 14                         []
# 15                        NaN
# 16                         []
# 17                         []
# 18                         []
#
#                                                 kinds              levels  \
# 0   [major_ascend, nya_overflight, sveabreen_glaci...         [100, 9700]
# 1                                        [high_level]              [9800]
# 2                                   [holding_pattern]        [9800, 9800]
# 3                                        [high_level]              [9800]
# 4                                        [short_turn]                 NaN
# 5                   [high_level, a-train_underflight]              [9700]
# 6                                        [short_turn]                 NaN
# 7                                        [high_level]              [9700]
# 8                                        [short_turn]                 NaN
# 9                                        [high_level]              [9800]
# 10             [cross_pattern, polarstern_overflight]        [9600, 9700]
# 11                                    [large_descend]         [9700, 200]
# 12                                       [short_turn]                 NaN
# 13                                     [large_ascend]        [2400, 9700]
# 14                                       [high_level]              [9700]
# 15                                       [short_turn]                 NaN
# 16                                       [high_level]              [9800]
# 17                    [cross_pattern, nya_overflight]  [9800, 9800, 9800]
# 18                                    [major_descend]         [9800, 100]
#
#                  name           segment_id               start  \
# 0        major ascend    ACLOUD_P5_RF14_ma 2017-06-08 07:36:50
# 1        high level 1  ACLOUD_P5_RF14_hl01 2017-06-08 08:08:54
# 2   holding pattern 1  ACLOUD_P5_RF14_ho01 2017-06-08 08:25:57
# 3        high level 2  ACLOUD_P5_RF14_hl02 2017-06-08 08:36:30
# 4          short turn                  NaN 2017-06-08 08:58:26
# 5        high level 3  ACLOUD_P5_RF14_hl03 2017-06-08 08:59:08
# 6          short turn                  NaN 2017-06-08 09:30:30
# 7        high level 4  ACLOUD_P5_RF14_hl04 2017-06-08 09:31:41
# 8          short turn                  NaN 2017-06-08 09:51:04
# 9        high level 5  ACLOUD_P5_RF14_hl05 2017-06-08 09:51:33
# 10    cross pattern 1  ACLOUD_P5_RF14_cr01 2017-06-08 10:00:14
# 11    large descend 1  ACLOUD_P5_RF14_ld01 2017-06-08 10:10:51
# 12         short turn                  NaN 2017-06-08 11:02:02
# 13     large ascend 1  ACLOUD_P5_RF14_la01 2017-06-08 11:02:25
# 14       high level 6  ACLOUD_P5_RF14_hl06 2017-06-08 11:11:20
# 15         short turn                  NaN 2017-06-08 11:52:57
# 16       high level 7  ACLOUD_P5_RF14_hl07 2017-06-08 11:53:38
# 17    cross pattern 2  ACLOUD_P5_RF14_cr02 2017-06-08 12:05:14
# 18      major descend    ACLOUD_P5_RF14_md 2017-06-08 12:25:40
#
#                                                 parts
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'end': 2017-06-08 08:27:33, 'kinds': ['short...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  [{'end': 2017-06-08 10:03:14, 'irregularities'...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  [{'end': 2017-06-08 12:10:14, 'irregularities'...
# 18                                                NaN

# %% [markdown]
# Plot the selected elements:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
# #### Example 2: Specific level

# %%
attribute = 'levels'
value = 9800

queried = ds.select(attribute, value)

df = pd.DataFrame(queried)
df
# Out:
#                                           dropsondes                 end  \
# 0                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:25:57
# 1                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:36:30
# 2  {'BAD': [], 'GOOD': ['P5_RF14_sonde02'], 'UGLY... 2017-06-08 08:58:26
# 3  {'BAD': [], 'GOOD': ['P5_RF14_sonde05'], 'UGLY... 2017-06-08 10:00:14
# 4  {'BAD': [], 'GOOD': ['P5_RF14_sonde07'], 'UGLY... 2017-06-08 12:05:14
# 5                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 12:25:40
# 6                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 12:51:25
#
#   irregularities                            kinds              levels  \
# 0             []                     [high_level]              [9800]
# 1             []                [holding_pattern]        [9800, 9800]
# 2             []                     [high_level]              [9800]
# 3             []                     [high_level]              [9800]
# 4             []                     [high_level]              [9800]
# 5             []  [cross_pattern, nya_overflight]  [9800, 9800, 9800]
# 6             []                  [major_descend]         [9800, 100]
#
#                 name           segment_id               start  \
# 0       high level 1  ACLOUD_P5_RF14_hl01 2017-06-08 08:08:54
# 1  holding pattern 1  ACLOUD_P5_RF14_ho01 2017-06-08 08:25:57
# 2       high level 2  ACLOUD_P5_RF14_hl02 2017-06-08 08:36:30
# 3       high level 5  ACLOUD_P5_RF14_hl05 2017-06-08 09:51:33
# 4       high level 7  ACLOUD_P5_RF14_hl07 2017-06-08 11:53:38
# 5    cross pattern 2  ACLOUD_P5_RF14_cr02 2017-06-08 12:05:14
# 6      major descend    ACLOUD_P5_RF14_md 2017-06-08 12:25:40
#
#                                                parts
# 0                                                NaN
# 1  [{'end': 2017-06-08 08:27:33, 'kinds': ['short...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  [{'end': 2017-06-08 12:10:14, 'irregularities'...
# 6                                                NaN

# %% [markdown]
# Plot the selected elements:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
# But what if we want only a specific level without ascend and descend? We can require that the attribute value is strictly equal to the one, that we give, i.e. thare no other values:

# %%
queried = ds.select(attribute, value, strict=True)

df = pd.DataFrame(queried)
df
# Out:
#                                           dropsondes                 end  \
# 0                {'BAD': [], 'GOOD': [], 'UGLY': []} 2017-06-08 08:25:57
# 1  {'BAD': [], 'GOOD': ['P5_RF14_sonde02'], 'UGLY... 2017-06-08 08:58:26
# 2  {'BAD': [], 'GOOD': ['P5_RF14_sonde05'], 'UGLY... 2017-06-08 10:00:14
# 3  {'BAD': [], 'GOOD': ['P5_RF14_sonde07'], 'UGLY... 2017-06-08 12:05:14
#
#   irregularities         kinds  levels          name           segment_id  \
# 0             []  [high_level]  [9800]  high level 1  ACLOUD_P5_RF14_hl01
# 1             []  [high_level]  [9800]  high level 2  ACLOUD_P5_RF14_hl02
# 2             []  [high_level]  [9800]  high level 5  ACLOUD_P5_RF14_hl05
# 3             []  [high_level]  [9800]  high level 7  ACLOUD_P5_RF14_hl07
#
#                 start
# 0 2017-06-08 08:08:54
# 1 2017-06-08 08:36:30
# 2 2017-06-08 09:51:33
# 3 2017-06-08 11:53:38

# %% [markdown]
# This functions only if the attribute has more values, as for level or kind. Now plot the selected elements:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %% [markdown]
# ### Query all segments with good (or bad) dropsondes

# %%
queried = ds.selectDropSondes('GOOD')

df = pd.DataFrame(queried)
df
# Out:
#                                           dropsondes                 end  \
# 0  {'BAD': [], 'GOOD': ['P5_RF14_sonde02'], 'UGLY... 2017-06-08 08:58:26
# 1  {'BAD': [], 'GOOD': ['P5_RF14_sonde03'], 'UGLY... 2017-06-08 09:30:30
# 2  {'BAD': [], 'GOOD': ['P5_RF14_sonde04'], 'UGLY... 2017-06-08 09:51:04
# 3  {'BAD': [], 'GOOD': ['P5_RF14_sonde05'], 'UGLY... 2017-06-08 10:00:14
# 4  {'BAD': [], 'GOOD': ['P5_RF14_sonde07'], 'UGLY... 2017-06-08 12:05:14
#
#   irregularities                              kinds  levels          name  \
# 0             []                       [high_level]  [9800]  high level 2
# 1             []  [high_level, a-train_underflight]  [9700]  high level 3
# 2             []                       [high_level]  [9700]  high level 4
# 3             []                       [high_level]  [9800]  high level 5
# 4             []                       [high_level]  [9800]  high level 7
#
#             segment_id               start
# 0  ACLOUD_P5_RF14_hl02 2017-06-08 08:36:30
# 1  ACLOUD_P5_RF14_hl03 2017-06-08 08:59:08
# 2  ACLOUD_P5_RF14_hl04 2017-06-08 09:31:41
# 3  ACLOUD_P5_RF14_hl05 2017-06-08 09:51:33
# 4  ACLOUD_P5_RF14_hl07 2017-06-08 11:53:38

# %% [markdown]
# Plot the selected elements:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig

# %%
queried = ds.selectDropSondes('BAD')

df = pd.DataFrame(queried)
df
# Out:
#                                           dropsondes                 end  \
# 0  {'BAD': ['P5_RF14_sonde06'], 'GOOD': [], 'UGLY... 2017-06-08 11:52:57
#
#   irregularities         kinds  levels          name           segment_id  \
# 0             []  [high_level]  [9700]  high level 6  ACLOUD_P5_RF14_hl06
#
#                 start
# 0 2017-06-08 11:11:20

# %% [markdown]
# Plot the selected elements:

# %%
for l in lines:
    ll = l.pop(0)
    ll.remove()
    
lines = []
for q in queried:
    start = q['start']
    end   = q['end']
    
    line = ax.plot(ds_gps.lon.sel(time=slice(start, end)),
                   ds_gps.lat.sel(time=slice(start, end)),
                   transform=ccrs.PlateCarree())
    lines.append(line)
    
fig
